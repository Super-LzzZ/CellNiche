# %%
! hostname
# Out:
# g05

# %%
! nvidia-smi
# Out:
# Thu Apr 30 23:12:57 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3080 Ti     On  |   00000000:D8:00.0 Off |                  N/A |
# | 30%   18C    P8             54W /  350W |       1MiB /  12288MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# enable autoreload
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import scanpy as sc
import numpy as np
import pandas as pd

import torch
from anndata import AnnData
import anndata
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
plt.rcParams['pdf.fonttype'] = 42
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.set_figure_params(dpi=300,
                     dpi_save=1200,
#                      facecolor='w',
#                      frameon=False, # frameon=True
#                      figsize=(4,4)
                    ) 
# %config InlineBackend.figure_format='retina'
# %matplotlib inline
# Out:
# scanpy==1.10.3 anndata==0.10.9 umap==0.5.9.post2 numpy==1.26.4 scipy==1.13.1 pandas==2.2.2 scikit-learn==1.6.1 statsmodels==0.14.5 igraph==0.11.9 pynndescent==0.5.13

# %%
import sys

repo_path = "/share/home/liangzhongming/phd_code/ModelTest/CellNiche"

if repo_path in sys.path:
    sys.path.remove(repo_path)

sys.path.insert(0, repo_path)

for m in list(sys.modules.keys()):
    if m == "cellniche" or m.startswith("cellniche."):
        del sys.modules[m]

import cellniche as cn

# %% [markdown]
# ### seed:best

# %%
! cat ../configs/CosMxMouseBrain.yaml
# Out:
# #  CellNiche multi-slice training config
# # ============================================================
# # ------------------------------------------------------------
# #  DATA & PRE-PROCESSING
# # ------------------------------------------------------------
# data_path: "/share/home/liangzhongming/phd_code/st_data/SpaLPdata/CosMx-cornoal-mouse-brain/"
# dataset: "CosMxMouseBrain"
# # Cell identity label in adata.obs.
# # Required when embedding_type is "pheno" or "pheno_expr".
# # Not required when embedding_type is "expr".
# phenoLabels: null
# # Ground-truth niche / region label in adata.obs.
# # Optional. Set to null if no ground-truth annotation is available.
# nicheLabels: 'spatialClusteringAssignments'
# # Input feature mode:
# #   "pheno"      : use one-hot encoded phenoLabels as input features
# #   "expr"       : use adata.X as input features
# #   "pheno_expr" : use phenoLabels as model input and adata.X for expression-based positive-pair construction
# ...

# %%
CosMxMouseBrain = cn.cli(["--config", "../configs/CosMxMouseBrain.yaml"])
# Out:
# 23:13:06 INFO: Seed: 3117
# 23:13:06 INFO: Using device: cuda
# 23:13:07 INFO: Average number of neighbors per node: 8.0
# 23:13:07 INFO: Loaded CosMxMouseBrain: 48180 nodes, 388524 edges, 950 expression features
# 23:13:08 INFO: loading_time: 1.84s
# 23:13:09 INFO: Epoch 1 Step 0001 contrast_loss=8.3709, recon_loss=0.0000
# 23:13:09 INFO: Epoch 1 Step 0002 contrast_loss=8.2052, recon_loss=0.0000
# 23:13:09 INFO: Epoch 1 Step 0003 contrast_loss=8.0670, recon_loss=0.0000
# 23:13:09 INFO: Epoch 1 Step 0004 contrast_loss=7.9372, recon_loss=0.0000
# 23:13:09 INFO: Epoch 1 Step 0005 contrast_loss=7.8798, recon_loss=0.0000
# 23:13:09 INFO: Epoch 1 Step 0006 contrast_loss=7.8458, recon_loss=0.0000
# 23:13:09 INFO: Epoch 1 Step 0007 contrast_loss=7.8391, recon_loss=0.0000
# 23:13:09 INFO: Epoch 1 Step 0008 contrast_loss=7.7988, recon_loss=0.0000
# 23:13:09 INFO: Epoch 1 Step 0009 contrast_loss=7.7776, recon_loss=0.0000
# ...

# %%
CosMxMouseBrain
# Out:
# AnnData object with n_obs × n_vars = 48180 × 950
#     obs: 'spatialClusteringAssignments', 'kmeans'
#     uns: 'RNA_nbclust_clusters_colors', 'spatialClusteringAssignments_colors'
#     obsm: 'spatial', 'CellNiche'

# %% [markdown]
# ### seed:null

# %%
! cat ../configs/CosMxMouseBrain.yaml
# Out:
# #  CellNiche multi-slice training config
# # ============================================================
# # ------------------------------------------------------------
# #  DATA & PRE-PROCESSING
# # ------------------------------------------------------------
# data_path: "/share/home/liangzhongming/phd_code/st_data/SpaLPdata/CosMx-cornoal-mouse-brain/"
# dataset: "CosMxMouseBrain"
# # Cell identity label in adata.obs.
# # Required when embedding_type is "pheno" or "pheno_expr".
# # Not required when embedding_type is "expr".
# phenoLabels: null
# # Ground-truth niche / region label in adata.obs.
# # Optional. Set to null if no ground-truth annotation is available.
# nicheLabels: 'spatialClusteringAssignments'
# # Input feature mode:
# #   "pheno"      : use one-hot encoded phenoLabels as input features
# #   "expr"       : use adata.X as input features
# #   "pheno_expr" : use phenoLabels as model input and adata.X for expression-based positive-pair construction
# ...

# %%
CosMxMouseBrain = cn.cli(["--config", "../configs/CosMxMouseBrain.yaml"])
# Out:
# 23:15:52 INFO: Seed: 3692
# 23:15:52 INFO: Using device: cuda
# 23:15:54 INFO: Average number of neighbors per node: 8.0
# 23:15:54 INFO: Loaded CosMxMouseBrain: 48180 nodes, 388524 edges, 950 expression features
# 23:15:54 INFO: loading_time: 1.31s
# 23:15:54 INFO: Epoch 1 Step 0001 contrast_loss=8.3867, recon_loss=0.0000
# 23:15:54 INFO: Epoch 1 Step 0002 contrast_loss=8.2130, recon_loss=0.0000
# 23:15:55 INFO: Epoch 1 Step 0003 contrast_loss=8.0630, recon_loss=0.0000
# 23:15:55 INFO: Epoch 1 Step 0004 contrast_loss=7.9571, recon_loss=0.0000
# 23:15:55 INFO: Epoch 1 Step 0005 contrast_loss=7.8886, recon_loss=0.0000
# 23:15:55 INFO: Epoch 1 Step 0006 contrast_loss=7.8482, recon_loss=0.0000
# 23:15:55 INFO: Epoch 1 Step 0007 contrast_loss=7.8431, recon_loss=0.0000
# 23:15:55 INFO: Epoch 1 Step 0008 contrast_loss=7.7784, recon_loss=0.0000
# 23:15:55 INFO: Epoch 1 Step 0009 contrast_loss=7.7885, recon_loss=0.0000
# ...

# %%
CosMxMouseBrain = cn.cli(["--config", "../configs/CosMxMouseBrain.yaml"])
# Out:
# 23:16:06 INFO: Seed: 212
# 23:16:06 INFO: Using device: cuda
# 23:16:08 INFO: Average number of neighbors per node: 8.0
# 23:16:08 INFO: Loaded CosMxMouseBrain: 48180 nodes, 388524 edges, 950 expression features
# 23:16:08 INFO: loading_time: 1.28s
# 23:16:08 INFO: Epoch 1 Step 0001 contrast_loss=8.3702, recon_loss=0.0000
# 23:16:08 INFO: Epoch 1 Step 0002 contrast_loss=8.2430, recon_loss=0.0000
# 23:16:08 INFO: Epoch 1 Step 0003 contrast_loss=8.0440, recon_loss=0.0000
# 23:16:08 INFO: Epoch 1 Step 0004 contrast_loss=7.9572, recon_loss=0.0000
# 23:16:08 INFO: Epoch 1 Step 0005 contrast_loss=7.9047, recon_loss=0.0000
# 23:16:08 INFO: Epoch 1 Step 0006 contrast_loss=7.8395, recon_loss=0.0000
# 23:16:08 INFO: Epoch 1 Step 0007 contrast_loss=7.8193, recon_loss=0.0000
# 23:16:08 INFO: Epoch 1 Step 0008 contrast_loss=7.7926, recon_loss=0.0000
# 23:16:09 INFO: Epoch 1 Step 0009 contrast_loss=7.8133, recon_loss=0.0000
# ...

# %%
CosMxMouseBrain = cn.cli(["--config", "../configs/CosMxMouseBrain.yaml"])
# Out:
# 23:16:20 INFO: Seed: 3246
# 23:16:20 INFO: Using device: cuda
# 23:16:21 INFO: Average number of neighbors per node: 8.0
# 23:16:21 INFO: Loaded CosMxMouseBrain: 48180 nodes, 388524 edges, 950 expression features
# 23:16:21 INFO: loading_time: 1.28s
# 23:16:22 INFO: Epoch 1 Step 0001 contrast_loss=8.3608, recon_loss=0.0000
# 23:16:22 INFO: Epoch 1 Step 0002 contrast_loss=8.2195, recon_loss=0.0000
# 23:16:22 INFO: Epoch 1 Step 0003 contrast_loss=8.0450, recon_loss=0.0000
# 23:16:22 INFO: Epoch 1 Step 0004 contrast_loss=7.9294, recon_loss=0.0000
# 23:16:22 INFO: Epoch 1 Step 0005 contrast_loss=7.8647, recon_loss=0.0000
# 23:16:22 INFO: Epoch 1 Step 0006 contrast_loss=7.8224, recon_loss=0.0000
# 23:16:22 INFO: Epoch 1 Step 0007 contrast_loss=7.8410, recon_loss=0.0000
# 23:16:22 INFO: Epoch 1 Step 0008 contrast_loss=7.7934, recon_loss=0.0000
# 23:16:22 INFO: Epoch 1 Step 0009 contrast_loss=7.7925, recon_loss=0.0000
# ...
